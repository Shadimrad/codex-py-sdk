# %% [markdown]
# # Quickstart
# Minimal sync flow with fluent conversation helpers.

# %%
from codex_app_server import AppServerClient

with AppServerClient() as client:
    client.initialize()
    thread = client.thread_start_session(model="gpt-5")
    result = thread.ask_result("Give me 3 bullet points about SIMD")
    print(result.text)
